# %%
# %matplotlib inline

# %%
from ipywidgets import FloatProgress
from IPython.display import display

# %%
import pandas as pd
import fuzzywuzzy.process as fwp

# %%
mfg_firm = pd.read_csv('../data/MfgFirm.csv')

# %%
mfg_firm.size
# Out:
# 17976

# %%
mfg_firm.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>RecallID</th>
#       <th>RecallNumber</th>
#       <th>MfgFirm</th>
#       <th>caseID</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8223</td>
#       <td>18073</td>
#       <td>Western Gas Partners LP, of The Woodlands, Texas</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>8221</td>
#       <td>18711</td>
#       <td>HealthPostures LLC, Prior Lake, Minn.</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8220</td>
#       <td>18069</td>
#       <td>Rocky Mountain Bicycles, of Canada</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8218</td>
#       <td>18710</td>
#       <td>Golden Chang, of China</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>8219</td>
#       <td>18071</td>
#       <td>Golden Forest, of Vietnam</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
us_company_codes = pd.read_excel('../data/All US Company codes in COMPUSTAT.xlsx')

# %%
us_company_codes.size
# Out:
# 1437360

# %%
us_company_codes.head()
# Out:
#    Global Company Key   Data Date  Data Year - Fiscal Industry Format  \
# 0                1004  05/31/2010              2009.0            INDL
# 1                1004  05/31/2011              2010.0            INDL
# 2                1004  05/31/2012              2011.0            INDL
# 3                1004  05/31/2013              2012.0            INDL
# 4                1004  05/31/2014              2013.0            INDL
#
#   Level of Consolidation - Company Annual Descriptor Population Source  \
# 0                                                  C                 D
# 1                                                  C                 D
# 2                                                  C                 D
# 3                                                  C                 D
# 4                                                  C                 D
#
#   Data Format Ticker Symbol   CUSIP Company Name ISO Currency Code  \
# 0         STD           AIR  361105     AAR CORP               USD
# 1         STD           AIR  361105     AAR CORP               USD
# 2         STD           AIR  361105     AAR CORP               USD
# 3         STD           AIR  361105     AAR CORP               USD
# 4         STD           AIR  361105     AAR CORP               USD
#
#    CIK Number Active/Inactive Status Marker  \
# 0      1750.0                             A
# 1      1750.0                             A
# 2      1750.0                             A
# 3      1750.0                             A
# 4      1750.0                             A
#
#   Current ISO Country Code - Incorporation County Code
# 0                                      USA         NaN
# 1                                      USA         NaN
# 2                                      USA         NaN
# 3                                      USA         NaN
# 4                                      USA         NaN

# %%
mfg_firm_names = mfg_firm[['MfgFirm']]
mfg_firm_names.head()
# Out:
#                                             MfgFirm
# 0  Western Gas Partners LP, of The Woodlands, Texas
# 1             HealthPostures LLC, Prior Lake, Minn.
# 2                Rocky Mountain Bicycles, of Canada
# 3                            Golden Chang, of China
# 4                         Golden Forest, of Vietnam

# %%
company_codes__no_duplicates = us_company_codes[['Company Name']].drop_duplicates(keep='last')
company_codes__no_duplicates.head()
# Out:
#                     Company Name
# 7                       AAR CORP
# 8     ADC TELECOMMUNICATIONS INC
# 16   AMERICAN AIRLINES GROUP INC
# 23       CECO ENVIRONMENTAL CORP
# 39  ASA GOLD AND PRECIOUS METALS

# %%
company_names = list(set(company_codes__no_duplicates['Company Name']))
len(company_names)
# Out:
# 15989

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
fuzz.token_sort_ratio('Western Gas Partners LP, of The Woodlands, Texas', 'WESTERN GAS PARTNERS LP')
# Out:
# 67

# %%
name = 'Western Gas Partners LP, of The Woodlands, Texas'
process.extractOne(name, company_names)
# Out:
# ('WESTERN GAS PARTNERS LP', 90)

# %%
name = 'HealthPostures LLC, Prior Lake, Minn.'
process.extractBests(name, company_names)
# Out:
# [('LIN MEDIA LLC', 86),
#  ('GYRODYNE LLC', 86),
#  ('CITYCENTER HOLDINGS LLC', 86),
#  ('JEFFERIES GROUP LLC', 86),
#  ('CHRYSLER GROUP LLC', 86)]

# %%
f = FloatProgress(min=0, max=mfg_firm_names.size)
display(f)

FUZZYWUZZY_THREASHOLD = 90


mapping = dict()
for row in mfg_firm_names.iterrows():
    mfg_firm_name = row[1]['MfgFirm']
    
    # fuzzywuzzy match with company_names
    company_name, score = process.extractOne(mfg_firm_name, company_names)
    mapping[mfg_firm_name] = (company_name, score) if score >= FUZZYWUZZY_THREASHOLD else (None, score)
    
    f.value += 1
# Out:
# FloatProgress(value=0.0, max=4494.0)

# %%
mapping
# Out:
# {'Western Gas Partners LP, of The Woodlands, Texas': ('WESTERN GAS PARTNERS LP',
#   90),
#  'HealthPostures LLC, Prior Lake, Minn.': (None, 86),
#  'Rocky Mountain Bicycles, of Canada': (None, 86),
#  'Golden Chang, of China': (None, 86),
#  'Golden Forest, of Vietnam': (None, 86),
#  'American Honda Motor Company Inc., of Torrance, Calif.': (None, 86),
#  'Deere & Company, of Moline, Ill.': ('DEERE & CO', 90),
#  'Yueqing City Island Fiber Optic Christmas Tree Plant, of China': (None, 86),
#  'Polaris Industries Inc., of Medina, Minn.': ('POLARIS INDUSTRIES INC', 90),
#  'Manu Changzhou Future International Business Mafacturer, from China': (None,
#   86)}

# %%
def set_company_name(row):
    mfg_firm_name = row.MfgFirm
    return mapping[mfg_firm_name]
        
mfg_firm['company_name'] = mfg_firm.apply(set_company_name, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-d2ccf9c33879> in <module>()
#       4
#       5
# ----> 6 mfg_firm['company_name'] = mfg_firm.apply(set_company_name, axis=1)
#
# ~/projects/notebooks/venv/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# ~/projects/notebooks/venv/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~/projects/notebooks/venv/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~/projects/notebooks/venv/lib/python3.6/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-37-d2ccf9c33879> in set_company_name(row)
#       1 def set_company_name(row):
#       2     mfg_firm_name = row.MfgFirm
# ----> 3     return mapping[mfg_firm_name]
#       4
#       5
#
# KeyError: ('ABEST Technology Co., Ltd., of China', 'occurred at index 10')

# %%
mfg_firm
# Out:
#       RecallID  RecallNumber  \
# 0         8223         18073
# 1         8221         18711
# 2         8220         18069
# 3         8218         18710
# 4         8219         18071
# 5         8216         18072
# 6         8215         18709
# 7         8212         18707
# 8         8213         18708
# 9         8211         18066
# 10        8210         18065
# 11        8205         18059
# 12        8206         18061
# 13        8203         18058
# 14        8204         18705
# 15        8202         18057
# 16        8199         18053
# 17        8196         18051
# 18        8193         18049
# 19        8192         18046
# 20        8187         18041
# 21        8189         18044
# 22        8185         18702
# 23        8183         18037
# 24        8182         18036
# 25        8169         18021
# 26        8168         18020
# 27        8167         18019
# 28        8166         18018
# 29        8165         18017
# ...        ...           ...
# 4464      4181          8165
# 4465      4181          8165
# 4466      4178          8161
# 4467      4178          8161
# 4468      4178          8161
# 4469      4175          8158
# 4470      4175          8158
# 4471      4179          8162
# 4472      4179          8162
# 4473      4177          8160
# 4474      4177          8160
# 4475      4176          8159
# 4476      4176          8159
# 4477      4176          8159
# 4478      4174          8157
# 4479      4174          8157
# 6                       DEERE & CO
# 7     CHINA LODGING GROUP LTD -ADR
# 8           POLARIS INDUSTRIES INC
# 9     VANGUARD TOTAL INTERNATIONAL
# 10        COATES INTERNATIONAL LTD
# 11                  INDIA FUND INC
# 12                     SOUTHERN CO
# 13                   F N B CORP/FL
# 14                      DEERE & CO
# 15                     NORBORD INC
# 16              CPC OF AMERICA INC
# 17                     NORBORD INC
# 18                     NORBORD INC
# 19                     NORBORD INC
# 20                     NORBORD INC
# 21          SPDR S&P 500 ETF TRUST
# 22        SLEEP NUMBER CORPORATION
# 23                  ARCTIC CAT INC
# 24                     NORBORD INC
# 25              AEP TEXAS NORTH CO
# 26                     NORBORD INC
# 27    CHINA LODGING GROUP LTD -ADR
# 28          POLARIS INDUSTRIES INC
# 29                  ARCTIC CAT INC
# ...                            ...
# 4464    ALKALINE WATER COMPANY INC
# 4465   LEGG MASON DEV EX-US DIVERS
# 4466           DILLARDS INC  -CL A
# 4467                AIR LEASE CORP
# 4468                          None
# 4469                          None
# 4470            ELEVATE CREDIT INC
# 4471      SILVERADO GOLD MINES LTD
# 4472          LOWE'S COMPANIES INC
# 4473  OLLIE'S BARGAIN OUTLET HLDGS
# 4474                          None
# 4475  WISDOMTREE CDA Q D G IDX ETF
# 4476                          None
# 4477          LOWE'S COMPANIES INC
# 4478                          None
# 4479          LOWE'S COMPANIES INC
# 4480                HOME DEPOT INC
# 4481         LUFKIN INDUSTRIES INC
# 4482     ATACAMA PACIFIC GOLD CORP
# 4483                          None
# 4484                          None
# 4485                          None
# 4486  POWER 3 MEDICAL PRODUCTS INC
# 4487          LOWE'S COMPANIES INC
# 4488                HOME DEPOT INC
# 4489  ALLIED PPTYS REAL ESTATE INV
# 4490          INSIGNIA SYSTEMS INC
# 4491                          None
# 4492                          None
# 4493             TRACTOR SUPPLY CO
#
# [4494 rows x 5 columns]

# %%
merged = pd.merge(mfg_firm, 
                  us_company_codes,
                  left_on='company_name',
                  right_on='Company Name',
                  suffixes=['_firm_names','_company_codes'],
                  how='left')
# Out:
#                                                  MfgFirm  \
# 0       Western Gas Partners LP, of The Woodlands, Texas
# 1                  HealthPostures LLC, Prior Lake, Minn.
# 2                     Rocky Mountain Bicycles, of Canada
# 3                                 Golden Chang, of China
# 4                              Golden Forest, of Vietnam
# 5      American Honda Motor Company Inc., of Torrance...
# 6                       Deere & Company, of Moline, Ill.
# 7      Yueqing City Island Fiber Optic Christmas Tree...
# 8              Polaris Industries Inc., of Medina, Minn.
# 9      Manu Changzhou Future International Business M...
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 15959                                                NaN
# 15960                                                NaN
# 15961                                                NaN
# 15962                                                NaN
# 15963                                                NaN
# 15964                                                NaN
# 15965                                                NaN
# 15966                                                NaN
# 15967                                                NaN
# 15968                                                NaN
# 15969                                                NaN
# 15970                                                NaN
# 15971                                                NaN
# 15972                                                NaN
# 15973                                                NaN
# 15974                                                NaN
# 15975                                                NaN
# 15976                                                NaN
# 15977                                                NaN
# 15978                                                NaN
# 15979                                                NaN
# 15980                                                NaN
# 15981                                                NaN
# 15982                                                NaN
# 15983                                                NaN
# 15984                                                NaN
# 15985                                                NaN
# 15986                                                NaN
# 15987                                                NaN
# 15988                                                NaN
#
#                         firm_code                  Company Name
# 0         WESTERN GAS PARTNERS LP       WESTERN GAS PARTNERS LP
# 1          ATLAS ENERGY GROUP LLC        ATLAS ENERGY GROUP LLC
# 2          GENWORTH MI CANADA INC        GENWORTH MI CANADA INC
# 3                  CHINA FUND INC                CHINA FUND INC
# 4                SINO-FOREST CORP              SINO-FOREST CORP
# 5                     BLUCORA INC                   BLUCORA INC
# 6                      DEERE & CO                    DEERE & CO
# 7      U S CHINA MINING GROUP INC    U S CHINA MINING GROUP INC
# 8          POLARIS INDUSTRIES INC        POLARIS INDUSTRIES INC
# 9         MAGNA INTERNATIONAL INC       MAGNA INTERNATIONAL INC
# 10                            NaN                      AAR CORP
# 11                            NaN    ADC TELECOMMUNICATIONS INC
# 12                            NaN   AMERICAN AIRLINES GROUP INC
# 13                            NaN       CECO ENVIRONMENTAL CORP
# 14                            NaN  ASA GOLD AND PRECIOUS METALS
# 15                            NaN                      AVX CORP
# 16                            NaN    PINNACLE WEST CAPITAL CORP
# 17                            NaN                   AARON'S INC
# 18                            NaN           ABBOTT LABORATORIES
# 19                            NaN                 SERVIDYNE INC
# 20                            NaN                    WORLDS INC
# 21                            NaN                    ACETO CORP
# 22                            NaN                 MORGUARD CORP
# 23                            NaN             ACMAT CORP  -CL A
# 24                            NaN              ACME UNITED CORP
# 25                            NaN            RELM WIRELESS CORP
# 26                            NaN   ADAMS DIVERSIFIED EQUITY FD
# 27                            NaN  ADAMS RESOURCES & ENERGY INC
# 28                            NaN        ADVANCED MICRO DEVICES
# 29                            NaN          ASM INTERNATIONAL NV
# ...                           ...                           ...
# 15959                         NaN           TOUCHSTONE GOLD LTD
# 15960                         NaN  INTL AUTOMOTIVE COMPN  -REDH
# 15961                         NaN     GOLD MOUNTAIN MINING CORP
# 15962                         NaN      MYCELX TECHNOLOGIES CORP
# 15963                         NaN           AVIANCA HOLDINGS SA
# 15964                         NaN            NANO DIMENSION LTD
# 15965                         NaN               GI DYNAMICS INC
# 15966                         NaN        TAIWAN LIPOSOME CO LTD
# 15967                         NaN   LED MEDICAL DIAGNOSTICS INC
# 15968                         NaN                  TAMINCO CORP
# 15969                         NaN         SUNSHINE OILSANDS LTD
# 15970                         NaN                 FRONTLINE LTD
# 15971                         NaN              DBV TECHNOLOGIES
# 15972                         NaN     NORD ANGLIA EDUCATION INC
# 15973                         NaN   PLATFORM SPECIALTY PRODUCTS
# 15974                         NaN      CHIPMOS TECHNOLOGIES INC
# 15975                         NaN                     CELYAD SA
# 15976                         NaN            CARACAL ENERGY INC
# 15977                         NaN               SCORPIO BULKERS
# 15978                         NaN                  ALLEGION PLC
# 15979                         NaN            AGILITY HEALTH INC
# 15980                         NaN      NORDIC AMERICAN OFFSHORE
# 15981                         NaN                DORIAN LPG LTD
# 15982                         NaN               NOMAD FOODS LTD
# 15983                         NaN                    ARGEN-X SE
# 15984                         NaN            ATHENE HOLDING LTD
# 15985                         NaN           MIDATECH PHARMA PLC
# 15986                         NaN          NYX GAMING GROUP LTD
# 15987                         NaN                 MOTIF BIO PLC
# 15988                         NaN            ABCANN GLOBAL CORP
#
# [15989 rows x 3 columns]
